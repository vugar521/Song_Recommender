# %%
import pandas as pd

# %%
spotify2000 = pd.read_csv('../lab-not-hot-songs/Spotify-2000.csv')
spotify2000
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# ...

# %%
spotify_raw = spotify2000.copy()
spotify_raw
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# ...

# %%
spotify = spotify_raw.iloc[:, [1,2]]
spotify
# Out:
#                        Title                    Artist
# 0                    Sunrise               Norah Jones
# 1                Black Night               Deep Purple
# 2             Clint Eastwood                  Gorillaz
# 3              The Pretender              Foo Fighters
# 4     Waitin' On A Sunny Day         Bruce Springsteen
# ...                      ...                       ...
# 1989        Heartbreak Hotel             Elvis Presley
# 1990               Hound Dog             Elvis Presley
# 1991         Johnny B. Goode               Chuck Berry
# 1992               Take Five  The Dave Brubeck Quartet
# 1993          Blueberry Hill               Fats Domino
#
# [1994 rows x 2 columns]

# %%
spotify = spotify.rename(columns={'Title': 'song', 'Artist': 'artist'})
spotify
# Out:
#                         song                    artist
# 0                    Sunrise               Norah Jones
# 1                Black Night               Deep Purple
# 2             Clint Eastwood                  Gorillaz
# 3              The Pretender              Foo Fighters
# 4     Waitin' On A Sunny Day         Bruce Springsteen
# ...                      ...                       ...
# 1989        Heartbreak Hotel             Elvis Presley
# 1990               Hound Dog             Elvis Presley
# 1991         Johnny B. Goode               Chuck Berry
# 1992               Take Five  The Dave Brubeck Quartet
# 1993          Blueberry Hill               Fats Domino
#
# [1994 rows x 2 columns]

# %%
hot100=pd.read_csv('hot100.csv',index_col=0) 
hot100
# Out:
#                            song                                artist
# 0                       Flowers                           Miley Cyrus
# 1                     Kill Bill                                   SZA
# 2                      Creepin'  Metro Boomin, The Weeknd & 21 Savage
# 3                     Anti-Hero                          Taylor Swift
# 4                        Unholy                Sam Smith & Kim Petras
# ..                          ...                                   ...
# 95                      Hey Mor                  Ozuna Featuring Feid
# 96                Gato de Noche                Nengo Flow & Bad Bunny
# 97               Heart To Heart                           Mac DeMarco
# 98  Never Gonna Not Dance Again                                  P!nk
# 99       Dancin' In The Country                         Tyler Hubbard
#
# [100 rows x 2 columns]

# %%
spotify.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1989    False
# 1990    False
# 1991    False
# 1992    False
# 1993    False
# Length: 1994, dtype: bool

# %%
hot100['song'].isin(spotify['song']).value_counts()
# Out:
# False    98
# True      2
# Name: song, dtype: int64

# %%
pd.merge(hot100, spotify, on=['song'], how='inner')
# Out:
#           song            artist_x        artist_y
# 0  Do It Again  NLE Choppa & 2Rare      Steely Dan
# 1        Human        Cody Johnson     The Killers
# 2        Human        Cody Johnson  Rag'n'Bone Man

# %% [markdown]
# - There is no duplicated song in these two dataframes.

# %%
spotify.to_csv('not_hot.csv', index = False)
